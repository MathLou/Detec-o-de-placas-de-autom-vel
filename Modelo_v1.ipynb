# %% [markdown]
# #Treinando com o modelo YOLOV8 com os dados preparados
# ## Diretório de dados:
#   data
#   - images
#     - train (80% do dataset)
#     -val (20% do dataset)
#   - labels
#     - train (80% do dataset)
#     -val (20% do dataset)
# Notebook adaptado de [1]

# %%
ROOT_DIR ='/Users/mlair/Desktop/VS_clean/data'

# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Treinando o modelo
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.pt")  # load pre trained model

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "google_colab_config.yaml"), epochs=100)  # train the model
# Out:
# Ultralytics YOLOv8.2.98  Python-3.12.4 torch-2.4.1+cpu CPU (Intel Core(TM) i5-8265U 1.60GHz)
# ...

# %%
# Salvando resultados e modelo

# !scp -r /content/runs '/Users/mlair/Desktop/VS_clean/data'
# Out:
# The system cannot find the path specified.

# %% [markdown]
# Resultados

# %%
# Plotando matriz de confusão normalizada
from IPython.display import display, Image

Image(filename='/Users/mlair/Desktop/VS_clean/runs/detect first/train9/confusion_matrix_normalized.png', width=600)

# %%
# Plotando resultados com dataset de validação

Image(filename='/Users/mlair/Desktop/VS_clean/runs/detect first/train9/val_batch0_labels.jpg', width=600)

# %%
from PIL import Image
import matplotlib.pyplot as plt
from ultralytics import YOLO
import requests

# Carregar o modelo YOLOv8 pré-treinado
model_path = '/Users/mlair/Desktop/VS_clean/runs/detect first/train9/weights/best.pt'
model = YOLO(model_path)

# Fazer inferência com imagem da web
image_url = 'https://i.redd.it/kht6qtdh9ww91.jpg'
image = Image.open(requests.get(image_url, stream=True).raw)
results = model(image)

# Plotar a imagem com os bounding boxes
plt.imshow(results[0].plot(show=False))
plt.show()
# Out:
# 0: 480x640 (no detections), 83.4ms
# Speed: 16.8ms preprocess, 83.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# #Discussão
#
# O modelo foi incapaz de realizar uma inferência com imagem da web e obteve acurácia de zero. Algumas hipóteses de melhorias são consideradas no próximo modelo:
# * Data augmentation no dataset
# * Checar qualidade de anotações
# * Buscar outro dataset

# %% [markdown]
# #Referências
#
# [1] Computer vision engineer. YOLOv8 Object Detection Tutorial. 2024. Disponível em: https://www.youtube.com/watch?v=m9fH9OWn8YM. Acesso em: 20 set. 2024.
